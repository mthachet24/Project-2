# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
books_data = "Books_Data_Clean.csv"

# %%
books_df = pd.read_csv(books_data)

# %%
books_df
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# ...

# %%
books_df=books_df.drop(columns=['language_code'])

# %%
books_df['Book Name'] = books_df['Book Name'].astype(str)
clean = books_df[books_df['Book Name'].map(lambda x: x.isascii())]
clean.head(62)
# Out:
#     Publishing Year                                        Book Name  \
# 0            1975.0                                          Beowulf
# 1            1987.0                                 Batman: Year One
# 2            2015.0                                Go Set a Watchman
# 3            2008.0                  When You Are Engulfed in Flames
# 4            2011.0                         Daughter of Smoke & Bone
# ..              ...                                              ...
# 58           2012.0                                             Easy
# 59           1849.0                                David Copperfield
# 60           2007.0  The Absolutely True Diary of a Part-Time Indian
# 62           1968.0                             A Wizard of Earthsea
# 63           2000.0                            Because of Winn-Dixie
#
#                                                Author Author_Rating  \
# 0                              Unknown, Seamus Heaney        Novice
# ...

# %%
books_df[books_df['Author'].map(lambda x: x.isascii())]
clean.head()
# Out:
#    Publishing Year                        Book Name  \
# 0           1975.0                          Beowulf
# 1           1987.0                 Batman: Year One
# 2           2015.0                Go Set a Watchman
# 3           2008.0  When You Are Engulfed in Flames
# 4           2011.0         Daughter of Smoke & Bone
#
#                                               Author Author_Rating  \
# 0                             Unknown, Seamus Heaney        Novice
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                         Harper Lee        Novice
# 3                                      David Sedaris  Intermediate
# 4                                       Laini Taylor  Intermediate
#
#    Book_average_rating  Book_ratings_count          genre  gross sales  \
# 0                 3.42              155903  genre fiction      34160.0
# 1                 4.23              145267  genre fiction      12437.5
# ...

# %%
clean.dropna()
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author Author_Rating  \
# 0                                Unknown, Seamus Heaney        Novice
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                            Harper Lee        Novice
# ...
